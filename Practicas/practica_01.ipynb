# %% [markdown]
# <a href="https://colab.research.google.com/github/ibarra-fernando/Laboratorio-de-metodos-Cuantitativos-Aplicados-a-la-gestion/blob/main/Practicas/practica_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Clase 0 - 🐍 Introducción a Python y Análisis de Datos
