# %% [markdown]
# <a href="https://colab.research.google.com/github/ibarra-fernando/Laboratorio-de-metodos-Cuantitativos-Aplicados-a-la-gestion/blob/main/notebooks/Practicas/practica_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Clase 0 - 🐍 Introducción a Python y Análisis de Datos**

# %%
# Instalación de librerías necesarias
# !pip install numpy pandas matplotlib seaborn

# %%
# Operaciones básicas

16 ** (1/2)
# Out:
# 4.0

# %%
# Variables

a = 1
b = 2

a + b
# Out:
# 3

# %%
# Integers int() & Floats float()

a = 5
b = 5.0

print(type(a), type(b))
# Out:
# <class 'int'> <class 'float'>

# %%
# Strings str() (Texto)

c = "cualquier texto entre comillas simples o dobles es string"
d = "cualquier texto entre comillas simples o dobles es string"

# %%
# Método de mayúscula

sea_shells = 'she sells sea shells by the sea shore'

sea_shells.upper()
# Out:
# 'SHE SELLS SEA SHELLS BY THE SEA SHORE'

# %%
# Ejercicio: Convertí el siguiente string en mayúscula

texto = "hola mundo"

texto.upper()
# Out:
# 'HOLA MUNDO'

# %%
# Booleans True & False

print(True == 1, False == 0)
# Out:
# True True

# %%
# Ejercicio: Introducí una variable llamada edad y asígnale un valor a tu elección. Escribí una condición que compruebe si el cuadrado de la edad es menor que 625.

edad = 32
print((edad ** 2) < 625)
# Out:
# False

# %%
# Lists, Indexing & Slicing
list_1 = ['cucumber', 'pasta sauce', 'leftovers', 'margarine', 'tomato']

list_1[0]

cliente_1 = ["Carlos López", 34, "1425", "carlos.lopez@gmail.com"]

print(f'Hola {cliente_1[0]}, un gusto')
# Out:
# Hola Carlos López, un gusto

# %%
# List Comprehensions

whats_in_my_fridge = ['cucumber', 'pasta sauce', 'leftovers', 'margarine', 'tomato']

[len(dummy) for dummy in whats_in_my_fridge]
# Out:
# [8, 11, 9, 9, 6]

# %%
# Operaciones con lists

words_i_like = ['fuzzy', 'muffle', 'truck']

words_i_like.append("roar")

words_i_like.remove("fuzzy")

words_i_like
# Out:
# ['muffle', 'truck', 'roar']

# %%
# Ejercicio

numbers = [100000, 10, 1, .01, 100, 2]

numbers.pop(0)

numbers[0] = 33

numbers.append(33)

numbers_mul = [num*2 for num in numbers]

numbers_mul
# Out:
# [66, 2, 0.02, 200, 4, 66]

# %%
# Tuples

cool_tuple = ('ponies', 'unicorns', 'sharks with laser beams on their heads')

cool_tuple = list(cool_tuple)

cool_tuple
# Out:
# ['ponies', 'unicorns', 'sharks with laser beams on their heads']

# %%
# Control flow if, elif, else

toothbrushes_packed = 10 # ajusten esto a 0, 1 y más de 1 para ir viendo los resultados

if toothbrushes_packed == 0:
  toothbrushes_packed += 1
  print('Thanks for reminding me, I just packed', toothbrushes_packed, '!')
elif toothbrushes_packed == 1:
  print('All set! I already packed', toothbrushes_packed, '!')
else:
  print('Oops, looks like I put', toothbrushes_packed, 'in my bag. I\'ll just take one.') # Necesitamos poner \ delante de ' para que Python trate ' como un caracter y no como el final del string
  toothbrushes_packed=1 # resetea la variable a 1
# Out:
# Oops, looks like I put 10 in my bag. I'll just take one.

# %%
# Loops for

places_to_visit = ['area 51', 'bermuda triangle', 'el dorado']

place_name_length=[]

for place in places_to_visit:
  place_name_length.append(len(place))

place_name_length
# Out:
# [7, 16, 9]

# %%
# Dictionaries

l_countries_capitals = {'Lesotho' : 'Matheru', 'Laos' : 'Vientiane', 'Luxembourg' : 'Luxembourg'}

l_countries_capitals.keys()

l_countries_capitals.values()
# Out:
# dict_values(['Matheru', 'Vientiane', 'Luxembourg'])

# %%
# funciones

round(3.14, 1)
# Out:
# 3.1

# %%
# Crear funciones

def div_two(x):
    return x/2

div_two(25)
# Out:
# 12.5

# %% [markdown]
# # **Parte 2: Análisis de Datos con Pandas**
#
# Análisis de datos con énfasis en DataFrames

# %%
# Imoprtamos las librerías de hoy
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# Carga de datos desde el local

hmeq = pd.read_asv('../DF/hmeq.csv')

hmeq # Nos muestra la tabla

# Pandas -- Resumen de columnas e información central

hmeq.info()

# Resumen estadístico de datos

hmeq.describe()
